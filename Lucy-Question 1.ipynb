# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df=pd.read_csv("Arrest_Data_from_2010_to_Present.csv")

# %%
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0    4248313  02/24/2015  1310.0       20    Olympic                2022   37
# 1  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 2    4254777  02/26/2015  2010.0       19    Mission                1985   22
# 3    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 4    5615197  04/30/2019   615.0        6  Hollywood                 663   27
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        M            H                5.0                 Burglary
# 1        F            B                NaN                      NaN
# 2        M            H                6.0                  Larceny
# 3        M            H                3.0                  Robbery
# 4        M            O                5.0                 Burglary
#
#   Arrest Type Code     Charge Charge Description  \
# ...

# %%
df["Date_of_Arrest"]=pd.to_datetime(df["Arrest Date"])

# %%
df.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0    4248313  02/24/2015  1310.0       20    Olympic                2022   37
# 1  191811472  05/03/2019  1700.0       18  Southeast                1802   23
# 2    4254777  02/26/2015  2010.0       19    Mission                1985   22
# 3    5614161  04/29/2019  1040.0        8    West LA                 842   41
# 4    5615197  04/30/2019   615.0        6  Hollywood                 663   27
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        M            H                5.0                 Burglary
# 1        F            B                NaN                      NaN
# 2        M            H                6.0                  Larceny
# 3        M            H                3.0                  Robbery
# 4        M            O                5.0                 Burglary
#
#   Arrest Type Code     Charge Charge Description  \
# ...

# %%
df["year"]=df["Date_of_Arrest"].dt.year

# %%
df_2018=df[df["year"]==2018]

# %%
len(df_2018)
# Out:
# 104277

# %%
df_2018["Area Name"].value_counts()
# Out:
# Central        10951
# Hollywood       9715
# Rampart         7345
# Pacific         6778
# 77th Street     6259
# Van Nuys        6193
# Southwest       5927
# Newton          5427
# N Hollywood     4947
# Mission         4357
# Olympic         3898
# Harbor          3875
# Southeast       3601
# Hollenbeck      3590
# West Valley     3562
# Northeast       3452
# Devonshire      3146
# Topanga         3094
# Foothill        3006
# West LA         2687
# Wilshire        2467
# Name: Area Name, dtype: int64

# %%
dm=df_2018.Age.rank()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-d60a54e09d0e> in <module>
# ----> 1 dm=df_2018.Age.rank(quantile=0.95)
#
# TypeError: rank() got an unexpected keyword argument 'quantile'

# %%
x=df_2018[df_2018.Age>df_2018.Age.quantile(0.95)]

# %%
x
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 2619       5419280  09/11/2018   518.0        1      Central
# 4757       5463816  11/02/2018   915.0       16     Foothill
# 6698     182022778  12/20/2018  2025.0       20      Olympic
# 6753       5219953  01/31/2018  1730.0        1      Central
# 6762       5348245  06/23/2018  1100.0        3    Southwest
# ...            ...         ...     ...      ...          ...
# 1289969    5509593  12/31/2018  1927.0        3    Southwest
# 1289986    5509110  12/30/2018  2040.0       19      Mission
# 1290116    5509394  12/31/2018  1200.0        3    Southwest
# 1290121    5509927  12/31/2018  2355.0        8      West LA
# 1290308    5509383  12/31/2018  1130.0       15  N Hollywood
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 2619                    111   69        M            B               22.0
# 4757                   1612   63        M            B               16.0
# ...

# %%
x['Charge Group Description'].value_counts()
# Out:
# Miscellaneous Other Violations    773
# Drunkeness                        492
# Liquor Laws                       438
# Narcotic Drug Laws                424
# Aggravated Assault                400
# Driving Under Influence           381
# Other Assaults                    370
# Disorderly Conduct                208
# Larceny                           198
# Moving Traffic Violations         121
# Sex (except rape/prst)             93
# Weapon (carry/poss)                60
# Fraud/Embezzlement                 49
# Prostitution/Allied                45
# Robbery                            40
# Against Family/Child               36
# Vehicle Theft                      24
# Burglary                           24
# Gambling                           19
# Rape                               19
# Homicide                           10
# Disturbing the Peace                9
# Forgery/Counterfeit                 8
# Receive Stolen Property             4
# ...

# %%
x.loc[: , "Charge Group Description"]
# Out:
# 2619              Driving Under Influence
# 4757                   Narcotic Drug Laws
# 6698                  Prostitution/Allied
# 6753       Miscellaneous Other Violations
# 6762                   Aggravated Assault
#                         ...
# 1289969           Driving Under Influence
# 1289986    Miscellaneous Other Violations
# 1290116               Weapon (carry/poss)
# 1290121           Driving Under Influence
# 1290308    Miscellaneous Other Violations
# Name: Charge Group Description, Length: 5120, dtype: object

# %%
Vehicle_Theft=24
Robbery=40
Burglary=24
Receive_Stolen_Property=4
def summ(a,b,c,d):
     return a+b+c+d
total_arrestee=summ(Vehicle_Theft,Robbery,Burglary,Receive_Stolen_Property)

# %%
total_arrestee
# Out:
# 92

# %%
df_2018
# Out:
#          Report ID Arrest Date    Time  Area ID   Area Name  \
# 165        5213460  01/24/2018  1930.0        6   Hollywood
# 166        5257944  03/15/2018   310.0        7    Wilshire
# 167        5328813  06/01/2018  1800.0        3   Southwest
# 168        5336331  06/10/2018   200.0       13      Newton
# 169        5360731  07/07/2018  2330.0       18   Southeast
# ...            ...         ...     ...      ...         ...
# 1290652    5509442  12/31/2018  1400.0       19     Mission
# 1290661    5509487  12/31/2018  1545.0        1     Central
# 1290666    5509344  12/31/2018   720.0       11   Northeast
# 1290673    5509947  12/31/2018  2320.0        4  Hollenbeck
# 1290693    5509405  12/31/2018  1200.0       19     Mission
#
#          Reporting District  Age Sex Code Descent Code  Charge Group Code  \
# 165                     668   29        M            H               10.0
# 166                     743   33        F            O                1.0
# ...

# %%
y=df_2018["Charge Group Description"].drop[]

# %%
df_2018["Charge Group Description"].value_counts()
# Out:
# Miscellaneous Other Violations    17023
# Narcotic Drug Laws                10697
# Aggravated Assault                 9231
# Driving Under Influence            8918
# Other Assaults                     7907
# Larceny                            5129
# Drunkeness                         3769
# Moving Traffic Violations          3565
# Liquor Laws                        3481
# Weapon (carry/poss)                3396
# Vehicle Theft                      3257
# Prostitution/Allied                2970
# Robbery                            2787
# Disorderly Conduct                 2536
# Burglary                           1958
# Sex (except rape/prst)             1179
# Fraud/Embezzlement                 1061
# Against Family/Child                923
# Receive Stolen Property             455
# Forgery/Counterfeit                 415
# Rape                                315
# Homicide                            274
# Non-Criminal Detention              198
# ...

# %%
y=df_2018[df_2018["Charge Group Description"]=="Non-Criminal Detention"]
#y=df_2018[df_2018["Charge Group Description"]=="Pre-Delinquency"]

# %%
new_df=df_2018.drop(df_2018[df_2018["Charge Group Description"]=="Non-Criminal Detention"].index)

new_df_2018=new_df.drop(new_df[new_df["Charge Group Description"]=="Pre-Delinquency"].index)

# %%
new_df_2018["Charge Group Description"].value_counts()
# Out:
# Miscellaneous Other Violations    17023
# Narcotic Drug Laws                10697
# Aggravated Assault                 9231
# Driving Under Influence            8918
# Other Assaults                     7907
# Larceny                            5129
# Drunkeness                         3769
# Moving Traffic Violations          3565
# Liquor Laws                        3481
# Weapon (carry/poss)                3396
# Vehicle Theft                      3257
# Prostitution/Allied                2970
# Robbery                            2787
# Disorderly Conduct                 2536
# Burglary                           1958
# Sex (except rape/prst)             1179
# Fraud/Embezzlement                 1061
# Against Family/Child                923
# Receive Stolen Property             455
# Forgery/Counterfeit                 415
# Rape                                315
# Homicide                            274
# Gambling                            175
# ...

# %%
avg_age=new_df_2018.groupby(["Charge Group Description"]).mean()
print(avg_age.head)
# Out:
# <bound method NDFrame.head of                                    Report ID         Time    Area ID  \
# Charge Group Description
# Against Family/Child            5.355391e+06  1372.403034  11.253521
# Aggravated Assault              5.371929e+06  1301.963276  10.519120
# Burglary                        5.527964e+06  1223.551583  10.269152
# Disorderly Conduct              1.546133e+08  1223.168770   4.675079
# Disturbing the Peace            1.169235e+08  1303.775510   9.836735
# Driving Under Influence         5.503826e+06  1193.650706  11.211258
# Drunkeness                      1.708722e+08  1523.112762   8.333510
# Federal Offenses                5.328202e+06  1607.200000  11.360000
# Forgery/Counterfeit             2.181846e+07  1368.096386   9.296386
# Fraud/Embezzlement              1.214087e+07  1396.926484  10.893497
# Gambling                        1.482961e+08  1691.851429  13.342857
# Homicide                        5.343437e+06  1196.149635  11.145985
# ...

# %%
z_score=stats.zscore(avg_age['Age'])
z_score
# Out:
# array([ 0.15473346, -0.11167656, -1.08659029,  1.52674355,  0.99155085,
#         0.01339552,  2.17174816, -0.19718027, -0.15256004,  0.17303679,
#         1.54571468, -1.06740082, -0.27034217,  1.8289996 ,  0.15428483,
#        -0.24670122,  0.33889745, -0.19445294, -1.17945575,  0.06521076,
#        -0.74903519, -1.86013121,  0.51402431, -1.22392779, -1.13888574])

# %%
abs(max(z_score))
# Out:
# 2.1717481576567237
